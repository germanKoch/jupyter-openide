# %%
title = "Привет, notebook"
numbers = [1, 2, 3, 4, 5]

def greet(name):
    message = f"Здравствуйте, {name}!"
    return message








very_long_identifier = "This deliberately long line exercises wrapping and caret alignment when the notebook is opened again in a narrow editor viewport."
print(greet("мир"))

# %% [markdown]
# # Markdown regression
#
# First paragraph with **bold**, *italic*, and `inline_code`.
#
# 1. ordered one
# 2. ordered two
#
# | column | value |
# |:-------|------:|
# | left | right |
#
# ![green attachment](attachment:green.png)
#
# - item one
# - item two
#
# > quoted text
#
# ```python
# print("markdown code")
# ```

# %%
from pathlib import Path

path = Path.cwd()
print(path.exists())
